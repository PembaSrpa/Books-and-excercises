# %% [markdown]
# # Return values

# %%
#  an incorrect function that can end without returning a value:

def absolute_value_wrong(x):
    if x < 0:
        return -x
    if x > 0:
        return x

# same but has dead code at the end:

def absolute_value_extra_return(x):
    if x < 0:
        return -x
    else:
        return x

    return 'This is dead code'

# correct function but idiomatic:

def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False

# spot the errors or improve the style.

# 1: This function absolute_value_wrong fails to return a value if x is exactly 0

def absolute_value_fixed(x):
    if x < 0:
        return -x
    else:
        return x

# 2: This function absolute_value_extra_return exits before reaching the last line

def absolute_value_clean(x):
    if x < 0:
        return -x
    return x

# 3: This function is_divisible is not idiomatic

def is_divisible(x, y):
    return x % y == 0

# %% [markdown]
# ### Use incremental development to write a function called hypot that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments.
# ### Note that there’s a function in the math module called hypot that does the same thing, but you should not use it for this exercise!
# ### Even if you can write the function correctly on the first try, start with a function that always returns 0 and practice making small changes, testing as you go. When you are done, the function should only return a value—it should not display anything.
#
# -> Incremental development involves writing a small amount of code, testing it, and then adding the next piece. This helps you identify errors immediately.

# %%
def hypot(a, b):
    """
    takes a and b and returns the dummy value 0
    """
    return 0

# %%
# Test
hypot(3, 4)
# Out:
# 0

# %%
def hypot(a, b):
    """
    takes a and b and calculates the sum of squares but still returns the dummy value 0
    """
    sum_sq = a**2 + b**2
    return 0

# %%
# Test
hypot(3, 4)
# Out:
# 0

# %%
def hypot(a, b):
    """
    finally, complete the calculation with the square root
    """
    sum_sq = a**2 + b**2
    result = sum_sq**0.5
    return result

# %%
# Test
hypot(3, 4)
# Out:
# 5.0

# %%
# Write a boolean function, is_between(x, y, z), that returns True if x < y < z or if z < y < x, and False otherwise.

def is_between(x, y, z):
    if x < y < z or z < y < x:
        return True
    else:
        return False

# %%
# improved idiomatic function

def is_between(x, y, z):
    return (x < y < z) or (z < y < x)

# %% [markdown]
# The Ackermann function, A m, n , is defined as: \
# A (m, n) = { n + 1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if m = 0 \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; { A(m − 1, 1)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if m > 0 and n = 0 \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; { A(m − 1), A(m, n − 1)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if m > 0 and n > 0 .
#
# Write a function named ackermann that evaluates the Ackermann function. What happens if you call ackermann(5, 5)?

# %%
def ackerman(m, n):
    if m == 0:
        return n + 1
    elif m > 0 and n == 0:
        return ackerman(m - 1, 1)
    elif m > 0 and n > 0:
        return ackerman(m - 1, ackerman(m, n - 1))
    else:
        return None

# Test
ackerman(2, 3)
# Out:
# 9

# %%
# ackerman(5, 5)
# The program will likely crash because of recursion depth

# %%
# Write a function called gcd that takes parameters a and b and returns their greatest common divisor.

def gcd(a, b):
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

# Test
gcd(12, 15)
# Out:
# 3
